# %%
import requests
from bs4 import BeautifulSoup as bs
from datetime import date
import pandas as pd

# %%
#Get latest Cook Senate Ratings page
page = requests.get("https://cookpolitical.com/ratings/senate-race-ratings")

# %%
#Check response
page
# Out:
# <Response [200]>

# %%
#Convert to soup
soup = bs(page.content, 'html.parser')

# %%
# write soup to html to save when future ratings changes would overwrite
with open("senate-"+str(date.today())+".html", "w") as file:
    file.write(str(soup))

# %%
# --------- How to read it saved html soup ---------
# with open("senate-"+str(date.today())+".html", 'r') as f:
#     contents = f.read()
#     soupread = BeautifulSoup(contents, 'lxml')
# test = soupread.find_all('ul', class_='ratings-detail-page-table-7-column-ul')

# %%
#Find all elements including ratings
categories = soup.find_all('ul', class_='ratings-detail-page-table-7-column-ul')

# %%
dem=['DSOLID_DEMOCRAT',
'DLIKELY_DEMOCRAT',
'DLEAN_DEMOCRAT',
'DTOSS_UP',
'DLEAN_REPUBLICAN',
'DLIKELY_REPUBLICAN',
'DSOLID_REPUBLICAN','RSOLID_DEMOCRAT',
'RLIKELY_DEMOCRAT',
'RLEAN_DEMOCRAT',
'RTOSS_UP',
'RLEAN_REPUBLICAN',
'RLIKELY_REPUBLICAN',
'RSOLID_REPUBLICAN']

# %%
#Get state names & incumbent names
catLists=[]
for cat in categories:
    catLists.append([elem.get_text().strip('\n') for elem in cat.select("li")])

# %%
#Convert to dataframe with columns as ratings categories
df= pd.DataFrame(catLists).transpose()

# %%
df.columns=dem

# %%
df
# Out:
#   DSOLID_DEMOCRAT DLIKELY_DEMOCRAT DLEAN_DEMOCRAT DTOSS_UP DLEAN_REPUBLICAN  \
# 0        DE-Coons             None      MI-Peters     None         AL-Jones
# 1       IL-Durbin             None           None     None             None
# 2       MA-Markey             None           None     None             None
# 3        MN-Smith             None           None     None             None
# 4      NH-Shaheen             None           None     None             None
# 5       NJ-Booker             None           None     None             None
# 6         NM-Open             None           None     None             None
# 7      OR-Merkley             None           None     None             None
# 8         RI-Reed             None           None     None             None
# 9       VA-Warner             None           None     None             None
#
#   DLIKELY_REPUBLICAN DSOLID_REPUBLICAN RSOLID_DEMOCRAT RLIKELY_DEMOCRAT  \
# 0               None              None            None             None
# 1               None              None            None             None
# 2               None              None            None             None
# 3               None              None            None             None
# 4               None              None            None             None
# 5               None              None            None             None
# 6               None              None            None             None
# 7               None              None            None             None
# 8               None              None            None             None
# 9               None              None            None             None
#
#   RLEAN_DEMOCRAT     RTOSS_UP RLEAN_REPUBLICAN RLIKELY_REPUBLICAN  \
# 0     AZ-McSally  GA-Loeffler      AK-Sullivan       KY-McConnell
# 1     CO-Gardner    GA-Perdue          KS-Open      MS-Hyde-Smith
# 2           None     IA-Ernst        TX-Cornyn               None
# 3           None   ME-Collins             None               None
# 4           None    MT-Daines             None               None
# 5           None    NC-Tillis             None               None
# 6           None    SC-Graham             None               None
# 7           None         None             None               None
# 8           None         None             None               None
# 9           None         None             None               None
#
#   RSOLID_REPUBLICAN
# 0         AR-Cotton
# 1          ID-Risch
# 2        LA-Cassidy
# 3          NE-Sasse
# 4         OK-Inhofe
# 5         SD-Rounds
# 6           TN-Open
# 7   WV-Moore Capito
# 8           WY-Open
# 9              None

# %%
s = pd.melt(df).dropna()

# %%
#Separate 2-character state name
s['state']=s['value']
s['state']=s['state'].str.slice(stop=2)

# %%
#Separate incumbent name
s['name']=s['value']
s['name']=s['name'].str.slice(start=3)

# %%
#Get party currently holding seat
s['held']=s['variable']
s['held']=s['held'].str.slice(stop=1)

# %%
#Separate rating
s['projection']=s['variable']
s['projection']=s['projection'].str.slice(start=1)

# %%
s=s.drop(['variable','value'],axis=1)

# %%
#Create unique id for each seat
s['state_unique']=s['state']+"20"

# %%
#Fix Georgia id
s.iloc[14].state=s.iloc[14].state="GAsp"
s.iloc[14].state_unique=s.iloc[14].state_unique="GAsp"

# %%
#Merge with data on senate seats with no elections in 2020
noelections=pd.read_csv('senate-noelections.csv')

# %%
senate=pd.concat([s,noelections],axis=0)
# Out:
# /Users/helenarobertson/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
pd.set_option('display.max_rows', 500)

# %%
projOrder = ['noelectiondem','SOLID_DEMOCRAT','LIKELY_DEMOCRAT','LEAN_DEMOCRAT','TOSS_UP','LEAN_REPUBLICAN','LIKELY_REPUBLICAN','SOLID_REPUBLICAN','noelectionrep']

# %%
senate['projection']=pd.Categorical(senate.projection, 
                      categories=projOrder)

# %%
senate.sort_values('projection', inplace=True)

# %%
senatedata = pd.read_csv("senateall.csv")

# %%
senatedata.head()
# Out:
#   state_unique state_name           incumbent         challenger  \
# 0         MNno  Minnesota   Amy Klobuchar (D)                NaN
# 1         MEno      Maine      Angus King (I)                NaN
# 2        MDno2   Maryland      Ben Cardin (D)                NaN
# 3         NE20   Nebraska       Ben Sasse (R)  Chris Janicek (D)
# 4         VTno    Vermont  Bernie Sanders (I)                NaN
#
#             held_name  index
# 0   Amy Klobuchar (D)      3
# 1      Angus King (I)      4
# 2      Ben Cardin (D)      5
# 3       Ben Sasse (R)     67
# 4  Bernie Sanders (I)     25

# %%
senatedata
# Out:
#    state_unique      state_name                   incumbent  \
# 0          MNno       Minnesota           Amy Klobuchar (D)
# 1          MEno           Maine              Angus King (I)
# 2         MDno2        Maryland              Ben Cardin (D)
# 3          NE20        Nebraska               Ben Sasse (R)
# 4          VTno         Vermont          Bernie Sanders (I)
# 5          LA20       Louisiana            Bill Cassidy (R)
# 6          PAno    Pennsylvania           Bob Casey Jr. (D)
# 7          NJno      New Jersey            Bob Menendez (D)
# 8         HIno2          Hawaii            Brian Schatz (D)
# 9         NVno2          Nevada  Catherine Cortez Masto (D)
# 10         DE20        Delaware             Chris Coons (D)
# 11         CTno     Connecticut            Chris Murphy (D)
# 12         MDno        Maryland        Chris Van Hollen (D)
# 13         IAno            Iowa          Chuck Grassley (R)
# 14        NYno2        New York           Chuck Schumer (D)
# 15         MS20     Mississippi        Cindy Hyde-Smith (R)
# 16         NJ20      New Jersey             Cory Booker (D)
# 17         CO20        Colorado            Cory Gardner (R)
# 18         AK20          Alaska            Dan Sullivan (R)
# 19         GA20         Georgia            David Perdue (R)
# 20         NEno        Nebraska             Deb Fischer (R)
# 21         MIno        Michigan         Debbie Stabenow (D)
# 22         CAno      California        Dianne Feinstein (D)
# 23         IL20        Illinois             Dick Durbin (D)
# 50                      Jaime Harrison (D)          Lindsey Graham (R)     49
# 51                                     NaN          Lisa Murkowski (R)     98
# 52                                     NaN           Maggie Hassan (D)      8
# 53                                     NaN             Marco Rubio (R)     94
# 54                                     NaN          Maria Cantwell (D)     22
# 55                         Daniel Gade (R)             Mark Warner (D)     45
# 56                                     NaN        Marsha Blackburn (R)     79
# 57                          Mark Kelly (D)          Martha McSally (R)     46
# 58                                     NaN         Martin Heinrich (D)     26
# 59                                     NaN            Mazie Hirono (D)     10
# 60                                     NaN          Michael Bennet (D)     14
# 61                                     NaN              Mike Braun (R)     91
# 62                                     NaN              Mike Crapo (R)     92
# 63                                     NaN                Mike Lee (R)     81
# 64                          Dan Ahlers (D)             Mike Rounds (R)     69
# 65                         Amy McGrath (D)         Mitch McConnell (R)     60
# 66                                     NaN             Mitt Romney (R)     82
# 67                                     NaN              Pat Toomey (R)     76
# 68                                     NaN           Patrick Leahy (D)     24
# 69                                     NaN            Patty Murray (D)     23
# 70                                     NaN               Rand Paul (R)     85
# 71                                     NaN      Richard Blumenthal (D)     12
# 72                                     NaN            Richard Burr (R)     80
# 73                                     NaN          Richard Shelby (R)     97
# 74                                     NaN              Rick Scott (R)     95
# 75                                     NaN             Rob Portman (R)     74
# 76                                     NaN            Roger Wicker (R)     84
# 77                                     NaN             Ron Johnson (R)     88
# 78                                     NaN               Ron Wyden (D)     29
# 79                                     NaN               Roy Blunt (R)     86
# 80                                     NaN      Sheldon Whitehouse (D)     34
# 81               Paula Jean Swearengin (D)    Shelley Moore Capito (R)     62
# 82                                     NaN           Sherrod Brown (D)     30
# 83                       Steve Bullock (D)            Steve Daines (R)     51
# 84                         Sara Gideon (D)           Susan Collins (R)     52
# 85                                     NaN           Tammy Baldwin (D)     21
# 86                                     NaN         Tammy Duckworth (D)      9
# 87                                     NaN                Ted Cruz (R)     77
# 88                      Cal Cunningham (D)             Thom Tillis (R)     50
# 89                                     NaN               Tim Kaine (D)     27
# 90                                     NaN               Tim Scott (R)     83
# 91                         Jason Lewis (R)              Tina Smith (D)     37
# 92                                     NaN              Todd Young (R)     90
# 93                                     NaN              Tom Carper (D)     11
# 94            Rick Dale Harrington Jr. (L)              Tom Cotton (R)     63
# 95  Cynthia Lummis (R)/Merav Ben-David (D)               Mike Enzi (R)     61
# 96                                     NaN          Kelly Loeffler (R)     55
# 97  Roger Marshall (R)/Barbara Bollier (D)             Pat Roberts (R)     58
# 98    Ben Ray Lujan (D)/Mark Ronchetti (R)               Tom Udall (D)     42
# 99  Bill Hagerty (R)/Marquita Bradshaw (D)         Lamar Alexander (R)     70

# %%
senate = senate.merge(senatedata, on="state_unique")

# %%
#Reconfigure ratings
senateDict = {
    "noelectiondem":"No election",
    "noelectionrep": "No election",
    "SOLID_DEMOCRAT":"Solid Democrat",
   "LIKELY_DEMOCRAT":"Likely Democrat",
    "LEAN_DEMOCRAT":"Lean Democrat",
    "TOSS_UP":"Toss Up",
    "LEAN_REPUBLICAN":"Lean Repbulican",
    "LIKELY_REPUBLICAN":"Likely Repbulican",
    "SOLID_REPUBLICAN":"Solid Republican"
}

# %%
senate['rating']=senate['projection']

# %%
senate=senate.replace({"rating":senateDict})

# %%
senate=senate.reset_index(drop=True)

# %%
senate['index']=senate.index

# %%
senate.to_json('senate.json',orient='records')

# %%
senate
# Out:
#    held          name         projection state state_unique      state_name  \
# 0     D      Stabenow      noelectiondem    MI         MIno        Michigan
# 1     D        Tester      noelectiondem    MT         MTno         Montana
# 2     D     Klobuchar      noelectiondem    MN         MNno       Minnesota
# 3     I          King      noelectiondem    ME         MEno           Maine
# 4     D        Cardin      noelectiondem    MD        MDno2        Maryland
# 5     D    Van Hollen      noelectiondem    MD         MDno        Maryland
# 6     D        Warren      noelectiondem    MA         MAno   Massachusetts
# 7     D        Hassan      noelectiondem    NH         NHno   New Hampshire
# 8     D     Duckworth      noelectiondem    IL         ILno        Illinois
# 9     D        Mirono      noelectiondem    HI         HIno          Hawaii
# 10    D        Carper      noelectiondem    DE         DEno        Delaware
# 11    D    Blumenthal      noelectiondem    CT        CTno2     Connecticut
# 12    D        Murphy      noelectiondem    CT         CTno     Connecticut
# 13    D        Bennet      noelectiondem    CO         COno        Colorado
# 14    D        Harris      noelectiondem    CA        CAno2      California
# 15    D        Schatz      noelectiondem    HI        HIno2          Hawaii
# 16    D     Feinstein      noelectiondem    CA         CAno      California
# 17    D      Menendez      noelectiondem    NJ         NJno      New Jersey
# 18    D         Rosen      noelectiondem    NV         NVno          Nevada
# 19    D       Manchin      noelectiondem    WV         WVno   West Virginia
# 20    D       Baldwin      noelectiondem    WI         WIno       Wisconsin
# 21    D      Cantwell      noelectiondem    WA        WAno2      Washington
# 22    D        Murray      noelectiondem    WA         WAno      Washington
# 23    D         Leahy      noelectiondem    VT        VTno2         Vermont
# 24    I       Sanders      noelectiondem    VT         VTno         Vermont
# 25    D      Heinrich      noelectiondem    NM         NMno      New Mexico
# 26    D         Kaine      noelectiondem    VA         VAno        Virginia
# 27    D     Casey Jr.      noelectiondem    PA         PAno    Pennsylvania
# 28    D         Wyden      noelectiondem    OR         ORno          Oregon
# 29    D         Brown      noelectiondem    OH         OHno            Ohio
# 30    D       Schumer      noelectiondem    NY        NYno2        New York
# 31    D    Gillibrand      noelectiondem    NY         NYno        New York
# 32    D  Cortez Masto      noelectiondem    NV        NVno2          Nevada
# 33    D    Whitehouse      noelectiondem    RI         RIno    Rhode Island
# 34    D        Sinema      noelectiondem    AZ         AZno         Arizona
# 35    D         Coons     SOLID_DEMOCRAT    DE         DE20        Delaware
# 36    D         Smith     SOLID_DEMOCRAT    MN         MN20       Minnesota
# 37    D          Reed     SOLID_DEMOCRAT    RI         RI20    Rhode Island
# 38    D       Merkley     SOLID_DEMOCRAT    OR         OR20          Oregon
# 39    D          Open     SOLID_DEMOCRAT    NM         NM20      New Mexico
# 40    D        Booker     SOLID_DEMOCRAT    NJ         NJ20      New Jersey
# 41    D        Warner     SOLID_DEMOCRAT    VA         VA20        Virginia
# 42    D        Markey     SOLID_DEMOCRAT    MA         MA20   Massachusetts
# 43    D        Durbin     SOLID_DEMOCRAT    IL         IL20        Illinois
# 44    D       Shaheen     SOLID_DEMOCRAT    NH         NH20   New Hampshire
# 45    R       McSally      LEAN_DEMOCRAT    AZ         AZ20         Arizona
# 46    R       Gardner      LEAN_DEMOCRAT    CO         CO20        Colorado
# 47    D        Peters      LEAN_DEMOCRAT    MI         MI20        Michigan
# 48    R        Tillis            TOSS_UP    NC         NC20  North Carolina
# 49    R        Graham            TOSS_UP    SC         SC20  South Carolina
# 50    R        Daines            TOSS_UP    MT         MT20         Montana
# 51    R       Collins            TOSS_UP    ME         ME20           Maine
# 52    R         Ernst            TOSS_UP    IA         IA20            Iowa
# 53    R        Perdue            TOSS_UP    GA         GA20         Georgia
# 54    D         Jones    LEAN_REPUBLICAN    AL         AL20         Alabama
# 55    R      Sullivan    LEAN_REPUBLICAN    AK         AK20          Alaska
# 56    R        Cornyn    LEAN_REPUBLICAN    TX         TX20           Texas
# 57    R          Open    LEAN_REPUBLICAN    KS         KS20          Kansas
# 58    R     McConnell  LIKELY_REPUBLICAN    KY         KY20        Kentucky
# 59    R    Hyde-Smith  LIKELY_REPUBLICAN    MS         MS20     Mississippi
# 60    R          Open   SOLID_REPUBLICAN    WY         WY20         Wyoming
# 61    R  Moore Capito   SOLID_REPUBLICAN    WV         WV20   West Virginia
# 62    R        Cotton   SOLID_REPUBLICAN    AR         AR20        Arkansas
# 63    R         Risch   SOLID_REPUBLICAN    ID         ID20           Idaho
# 64    R       Cassidy   SOLID_REPUBLICAN    LA         LA20       Louisiana
# 65    R         Sasse   SOLID_REPUBLICAN    NE         NE20        Nebraska
# 66    R        Inhofe   SOLID_REPUBLICAN    OK         OK20        Oklahoma
# 67    R        Rounds   SOLID_REPUBLICAN    SD         SD20    South Dakota
# 68    R          Open   SOLID_REPUBLICAN    TN         TN20       Tennessee
# 69    R        Cramer      noelectionrep    ND         NDno    North Dakota
# 70    R        Hoeven      noelectionrep    ND        NDno2    North Dakota
# 71    R       Fischer      noelectionrep    NE         NEno        Nebraska
# 72    R       Portman      noelectionrep    OH        OHno2            Ohio
# 73    R      Lankford      noelectionrep    OK         OKno        Oklahoma
# 74    R        Toomey      noelectionrep    PA        PAno2    Pennsylvania
# 75    R     Blackburn      noelectionrep    TN         TNno       Tennessee
# 76    R         Thune      noelectionrep    SD         SDno    South Dakota
# 77    R          Burr      noelectionrep    NC         NCno  North Carolina
# 78    R          Cruz      noelectionrep    TX         TXno           Texas
# 79    R           Lee      noelectionrep    UT         UTno            Utah
# 80    R        Romney      noelectionrep    UT        UTno2            Utah
# 81    R         Scott      noelectionrep    SC         SCno  South Carolina
# 82    R        Wicker      noelectionrep    MS         MSno     Mississippi
# 83    R       Kennedy      noelectionrep    LA         LAno       Louisiana
# 84    R         Blunt      noelectionrep    MO         MOno        Missouri
# 85    R       Johnson      noelectionrep    WI        WIno2       Wisconsin
# 86    R          Paul      noelectionrep    KY         KYno        Kentucky
# 87    R         Moran      noelectionrep    KS         KSno          Kansas
# 88    R         Young      noelectionrep    IN        INno2         Indiana
# 89    R         Braun      noelectionrep    IN         INno         Indiana
# 90    R         Crapo      noelectionrep    ID         IDno           Idaho
# 91    R      Grassley      noelectionrep    IA         IAno            Iowa
# 92    R         Rubio      noelectionrep    FL        FLno2         Florida
# 28               Ron Wyden (D)     28        No election
# 29           Sherrod Brown (D)     29        No election
# 30           Chuck Schumer (D)     30        No election
# 31      Kirsten Gillibrand (D)     31        No election
# 32  Catherine Cortez Masto (D)     32        No election
# 33      Sheldon Whitehouse (D)     33        No election
# 34          Kyrsten Sinema (D)     34        No election
# 35             Chris Coons (D)     35     Solid Democrat
# 36              Tina Smith (D)     36     Solid Democrat
# 37               Jack Reed (D)     37     Solid Democrat
# 38            Jeff Merkley (D)     38     Solid Democrat
# 39               Tom Udall (D)     39     Solid Democrat
# 40             Cory Booker (D)     40     Solid Democrat
# 41             Mark Warner (D)     41     Solid Democrat
# 42               Ed Markey (D)     42     Solid Democrat
# 43             Dick Durbin (D)     43     Solid Democrat
# 44          Jeanne Shaheen (D)     44     Solid Democrat
# 45          Martha McSally (R)     45      Lean Democrat
# 46            Cory Gardner (R)     46      Lean Democrat
# 47             Gary Peters (D)     47      Lean Democrat
# 48             Thom Tillis (R)     48            Toss Up
# 49          Lindsey Graham (R)     49            Toss Up
# 50            Steve Daines (R)     50            Toss Up
# 51           Susan Collins (R)     51            Toss Up
# 52              Joni Ernst (R)     52            Toss Up
# 53            David Perdue (R)     53            Toss Up
# 54              Doug Jones (D)     54    Lean Repbulican
# 55            Dan Sullivan (R)     55    Lean Repbulican
# 56             John Cornyn (R)     56    Lean Repbulican
# 57             Pat Roberts (R)     57    Lean Repbulican
# 58         Mitch McConnell (R)     58  Likely Repbulican
# 59        Cindy Hyde-Smith (R)     59  Likely Repbulican
# 60               Mike Enzi (R)     60   Solid Republican
# 61    Shelley Moore Capito (R)     61   Solid Republican
# 62              Tom Cotton (R)     62   Solid Republican
# 63               Jim Risch (R)     63   Solid Republican
# 64            Bill Cassidy (R)     64   Solid Republican
# 65               Ben Sasse (R)     65   Solid Republican
# 66              Jim Inhofe (R)     66   Solid Republican
# 67             Mike Rounds (R)     67   Solid Republican
# 68         Lamar Alexander (R)     68   Solid Republican
# 69            Kevin Cramer (R)     69        No election
# 70             John Hoeven (R)     70        No election
# 71             Deb Fischer (R)     71        No election
# 72             Rob Portman (R)     72        No election
# 73          James Lankford (R)     73        No election
# 74              Pat Toomey (R)     74        No election
# 75        Marsha Blackburn (R)     75        No election
# 76              John Thune (R)     76        No election
# 77            Richard Burr (R)     77        No election
# 78                Ted Cruz (R)     78        No election
# 79                Mike Lee (R)     79        No election
# 80             Mitt Romney (R)     80        No election
# 81               Tim Scott (R)     81        No election
# 82            Roger Wicker (R)     82        No election
# 83            John Kennedy (R)     83        No election
# 84               Roy Blunt (R)     84        No election
# 85             Ron Johnson (R)     85        No election
# 86               Rand Paul (R)     86        No election
# 87             Jerry Moran (R)     87        No election
# 88              Todd Young (R)     88        No election
# 89              Mike Braun (R)     89        No election
# 90              Mike Crapo (R)     90        No election
# 91          Chuck Grassley (R)     91        No election
# 92             Marco Rubio (R)     92        No election
# 93              Rick Scott (R)     93        No election
# 94            John Boozman (R)     94        No election
# 95          Richard Shelby (R)     95        No election
# 96          Lisa Murkowski (R)     96        No election
# 97             Josh Hawley (R)     97        No election
# 98           John Barrasso (R)     98        No election
